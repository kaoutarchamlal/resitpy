# %%
# importing csv file and making variables to store informartion in. 
import csv
with open('userreviews.csv', 'r', encoding= 'utf-8-sig') as userreviews:

    csv_reader = csv.reader(userreviews, delimiter=';')

    next(csv_reader, None)
    score = []
    authors = []
    score_kaoutar = 8.5
    favorite_movie = "tangled"
    count = 0
    avg = 0
    sum = 0



    for i in csv_reader:
        if (i[0]) == favorite_movie:
            sum+=float(i[1])
            count = count+1
            author=i[2]
            authors.append(i[2])
            print(author)
            print("the reviewer gave this movie a: " + (i[1]))
            print("the sum is: " + str(sum))
            print("the count is: " + str(count))
# Out:
# BlueDevilHawk1
# the reviewer gave this movie a: 10
# the sum is: 10.0
# the count is: 1
# Skytreader
# the reviewer gave this movie a: 10
# the sum is: 20.0
# the count is: 2
# spirona
# the reviewer gave this movie a: 10
# the sum is: 30.0
# the count is: 3
# JonnyFendi
# the reviewer gave this movie a: 9
# the sum is: 39.0
# the count is: 4
# kristen58
# the reviewer gave this movie a: 10
# the sum is: 49.0
# the count is: 5
# JasonGoalie
# the reviewer gave this movie a: 9
# the sum is: 58.0
# the count is: 6
# Supermom4
# the reviewer gave this movie a: 9
# the sum is: 67.0
# the count is: 7
# DrNegative
# the reviewer gave this movie a: 10
# the sum is: 77.0
# the count is: 8
# Palino007
# the reviewer gave this movie a: 9
# the sum is: 86.0
# the count is: 9
# heyitsmegrif4
# the reviewer gave this movie a: 9
# the sum is: 95.0
# the count is: 10
# Whalnar
# the reviewer gave this movie a: 10
# the sum is: 105.0
# the count is: 11
# Halfwelshman
# the reviewer gave this movie a: 9
# the sum is: 114.0
# the count is: 12
# Tranquilbez22
# the reviewer gave this movie a: 9
# the sum is: 123.0
# the count is: 13
# jordi
# the reviewer gave this movie a: 10
# the sum is: 133.0
# the count is: 14
# movielover64
# the reviewer gave this movie a: 10
# the sum is: 143.0
# the count is: 15
# Simpkj1
# the reviewer gave this movie a: 10
# the sum is: 153.0
# the count is: 16
# Eilrahc
# the reviewer gave this movie a: 10
# the sum is: 163.0
# the count is: 17
# Kidknowitall
# the reviewer gave this movie a: 10
# the sum is: 173.0
# the count is: 18
# Kalukalay
# the reviewer gave this movie a: 9
# the sum is: 182.0
# the count is: 19
# Rumblebeelove
# the reviewer gave this movie a: 9
# the sum is: 191.0
# the count is: 20
# AndrewUltimate
# the reviewer gave this movie a: 10
# the sum is: 201.0
# the count is: 21
# dinozgorawrr
# the reviewer gave this movie a: 9
# the sum is: 210.0
# the count is: 22
# Malasawas
# the reviewer gave this movie a: 10
# the sum is: 220.0
# the count is: 23
# Bullet97
# the reviewer gave this movie a: 10
# the sum is: 230.0
# the count is: 24
# Forrestgump1
# the reviewer gave this movie a: 9
# the sum is: 239.0
# the count is: 25
# InfamousPrince
# the reviewer gave this movie a: 10
# the sum is: 249.0
# the count is: 26
# gm101
# the reviewer gave this movie a: 8
# the sum is: 257.0
# the count is: 27
# heybuddymovies
# the reviewer gave this movie a: 8
# the sum is: 265.0
# the count is: 28
# zamarren
# the reviewer gave this movie a: 10
# the sum is: 275.0
# the count is: 29
# movie2187
# the reviewer gave this movie a: 10
# the sum is: 285.0
# the count is: 30
# Gari
# the reviewer gave this movie a: 10
# the sum is: 295.0
# the count is: 31
# billruller
# the reviewer gave this movie a: 9
# the sum is: 304.0
# the count is: 32
# gamer1
# the reviewer gave this movie a: 10
# the sum is: 314.0
# the count is: 33
# Zahara
# the reviewer gave this movie a: 10
# the sum is: 324.0
# the count is: 34
# MoeYaz
# the reviewer gave this movie a: 10
# the sum is: 334.0
# the count is: 35
# Annoymous1
# the reviewer gave this movie a: 10
# the sum is: 344.0
# the count is: 36
# Rox22
# the reviewer gave this movie a: 9
# the sum is: 353.0
# the count is: 37
# InspectorJ
# the reviewer gave this movie a: 8
# the sum is: 361.0
# the count is: 38
# vini1904
# the reviewer gave this movie a: 10
# the sum is: 371.0
# the count is: 39
# reneewallace
# the reviewer gave this movie a: 10
# the sum is: 381.0
# the count is: 40
# Jwv
# the reviewer gave this movie a: 9
# the sum is: 390.0
# the count is: 41
# Parade
# the reviewer gave this movie a: 10
# the sum is: 400.0
# the count is: 42
# Bethzaira
# the reviewer gave this movie a: 10
# the sum is: 410.0
# the count is: 43
# goopyGoop
# the reviewer gave this movie a: 9
# the sum is: 419.0
# the count is: 44
# grandpajoe6191
# the reviewer gave this movie a: 8
# the sum is: 427.0
# the count is: 45
# MizLemon
# the reviewer gave this movie a: 8
# the sum is: 435.0
# the count is: 46
# MovieLonely94
# the reviewer gave this movie a: 10
# the sum is: 445.0
# the count is: 47
# Ruler101
# the reviewer gave this movie a: 10
# the sum is: 455.0
# the count is: 48
# iluvmovies
# the reviewer gave this movie a: 1
# the sum is: 456.0
# the count is: 49
# rayray
# the reviewer gave this movie a: 6
# the sum is: 462.0
# the count is: 50
# Bikerjames
# the reviewer gave this movie a: 9
# the sum is: 471.0
# the count is: 51
# ari5610
# the reviewer gave this movie a: 3
# the sum is: 474.0
# the count is: 52
# JonnyTheGreat
# the reviewer gave this movie a: 6
# the sum is: 480.0
# the count is: 53
# Grothos
# the reviewer gave this movie a: 7
# the sum is: 487.0
# the count is: 54
# tazielin
# the reviewer gave this movie a: 5
# the sum is: 492.0
# the count is: 55
# TheQuietGamer
# the reviewer gave this movie a: 9
# the sum is: 501.0
# the count is: 56
# NaughtyDog
# the reviewer gave this movie a: 10
# the sum is: 511.0
# the count is: 57
# Potter17
# the reviewer gave this movie a: 7
# the sum is: 518.0
# the count is: 58
# spielbrick90
# the reviewer gave this movie a: 7
# the sum is: 525.0
# the count is: 59
# PurpleUrp
# the reviewer gave this movie a: 8
# the sum is: 533.0
# the count is: 60
# MovieCritic
# the reviewer gave this movie a: 0
# the sum is: 533.0
# the count is: 61
# TitaniumDragon
# the reviewer gave this movie a: 5
# the sum is: 538.0
# the count is: 62
# smijatov
# the reviewer gave this movie a: 5
# the sum is: 543.0
# the count is: 63
# Jacob
# the reviewer gave this movie a: 6
# the sum is: 549.0
# the count is: 64
# lasttimeisaw
# the reviewer gave this movie a: 6
# the sum is: 555.0
# the count is: 65
# libbie65
# the reviewer gave this movie a: 7
# the sum is: 562.0
# the count is: 66
# RayzorMoose
# the reviewer gave this movie a: 6
# the sum is: 568.0
# the count is: 67
# MrsBBaggins
# the reviewer gave this movie a: 2
# the sum is: 570.0
# the count is: 68
# lukechristiansc
# the reviewer gave this movie a: 5
# the sum is: 575.0
# the count is: 69
# EpicLadySponge
# the reviewer gave this movie a: 7
# the sum is: 582.0
# the count is: 70
# SimpsonFans
# the reviewer gave this movie a: 10
# the sum is: 592.0
# the count is: 71
# TVJerry
# the reviewer gave this movie a: 8
# the sum is: 600.0
# the count is: 72
# Anim8or
# the reviewer gave this movie a: 9
# the sum is: 609.0
# the count is: 73
# BubblegumImp
# the reviewer gave this movie a: 8
# the sum is: 617.0
# the count is: 74
# Shiira
# the reviewer gave this movie a: 9
# the sum is: 626.0
# the count is: 75
# brewcrewpride
# the reviewer gave this movie a: 8
# the sum is: 634.0
# the count is: 76
# PYRiAH
# the reviewer gave this movie a: 8
# the sum is: 642.0
# the count is: 77
# NickXoN
# the reviewer gave this movie a: 10
# the sum is: 652.0
# the count is: 78
# speno93
# the reviewer gave this movie a: 10
# the sum is: 662.0
# the count is: 79
# Pier
# the reviewer gave this movie a: 7
# the sum is: 669.0
# the count is: 80
# hellenn
# the reviewer gave this movie a: 8
# the sum is: 677.0
# the count is: 81
# hippiechick8ify
# the reviewer gave this movie a: 8
# the sum is: 685.0
# the count is: 82
# AKJBourne
# the reviewer gave this movie a: 10
# the sum is: 695.0
# the count is: 83
# KendylKlownfish
# the reviewer gave this movie a: 8
# the sum is: 703.0
# the count is: 84
# nutterjr
# the reviewer gave this movie a: 8
# the sum is: 711.0
# the count is: 85
# trish30
# the reviewer gave this movie a: 10
# the sum is: 721.0
# the count is: 86
# CitizenCharlie
# the reviewer gave this movie a: 7
# the sum is: 728.0
# the count is: 87
# jessetaylor25
# the reviewer gave this movie a: 8
# the sum is: 736.0
# the count is: 88
# lionalio
# the reviewer gave this movie a: 9
# the sum is: 745.0
# the count is: 89
# DrMovie
# the reviewer gave this movie a: 9
# the sum is: 754.0
# the count is: 90
# zogondragon
# the reviewer gave this movie a: 10
# the sum is: 764.0
# the count is: 91
# BamaFalstaff
# the reviewer gave this movie a: 9
# the sum is: 773.0
# the count is: 92
# randomdude
# the reviewer gave this movie a: 8
# the sum is: 781.0
# the count is: 93
# emjohnson54
# the reviewer gave this movie a: 9
# the sum is: 790.0
# the count is: 94
# KennElm
# the reviewer gave this movie a: 8
# the sum is: 798.0
# the count is: 95
# Broken_Shirt
# the reviewer gave this movie a: 7
# the sum is: 805.0
# the count is: 96
# GleekManiac
# the reviewer gave this movie a: 10
# the sum is: 815.0
# the count is: 97
# joelschnick
# the reviewer gave this movie a: 6
# the sum is: 821.0
# the count is: 98
# J-Shap
# the reviewer gave this movie a: 6
# the sum is: 827.0
# the count is: 99
# j30
# the reviewer gave this movie a: 8
# the sum is: 835.0
# the count is: 100
# lordjrs
# the reviewer gave this movie a: 9
# the sum is: 844.0
# the count is: 101
# WielderofKnives
# the reviewer gave this movie a: 8
# the sum is: 852.0
# the count is: 102
# aaronpaul121
# the reviewer gave this movie a: 7
# the sum is: 859.0
# the count is: 103
# Zilcell
# the reviewer gave this movie a: 7
# the sum is: 866.0
# the count is: 104
# cameronmorewood
# the reviewer gave this movie a: 8
# the sum is: 874.0
# the count is: 105
# worleyjamers
# the reviewer gave this movie a: 9
# the sum is: 883.0
# the count is: 106
# SEROJ
# the reviewer gave this movie a: 8
# the sum is: 891.0
# the count is: 107
# jeff_reviews
# the reviewer gave this movie a: 8
# the sum is: 899.0
# the count is: 108
# mapizarro
# the reviewer gave this movie a: 8
# the sum is: 907.0
# the count is: 109
# Iky009
# the reviewer gave this movie a: 8
# the sum is: 915.0
# the count is: 110
# GodotIsW8ing4U
# the reviewer gave this movie a: 9
# the sum is: 924.0
# the count is: 111
# TangledFan
# the reviewer gave this movie a: 10
# the sum is: 934.0
# the count is: 112
# Supersaiyan9000
# the reviewer gave this movie a: 8
# the sum is: 942.0
# the count is: 113
# IMAX500
# the reviewer gave this movie a: 10
# the sum is: 952.0
# the count is: 114
# thetvreviewman
# the reviewer gave this movie a: 9
# the sum is: 961.0
# the count is: 115
# ssyeon5643
# the reviewer gave this movie a: 9
# the sum is: 970.0
# the count is: 116
# nicholasbert
# the reviewer gave this movie a: 5
# the sum is: 975.0
# the count is: 117
# homer4president
# the reviewer gave this movie a: 7
# the sum is: 982.0
# the count is: 118
# MrMovieBuff
# the reviewer gave this movie a: 10
# the sum is: 992.0
# the count is: 119
# BasilZero
# the reviewer gave this movie a: 8
# the sum is: 1000.0
# the count is: 120
# CineAutoctono
# the reviewer gave this movie a: 8
# the sum is: 1008.0
# the count is: 121
# diegonelli
# the reviewer gave this movie a: 7
# the sum is: 1015.0
# the count is: 122
# Futuredirector
# the reviewer gave this movie a: 8
# the sum is: 1023.0
# the count is: 123
# bethanyrobben
# the reviewer gave this movie a: 7
# the sum is: 1030.0
# the count is: 124
# DavidTejada
# the reviewer gave this movie a: 9
# the sum is: 1039.0
# the count is: 125
# Daniel17
# the reviewer gave this movie a: 9
# the sum is: 1048.0
# the count is: 126
# MonkiReviews
# the reviewer gave this movie a: 7
# the sum is: 1055.0
# the count is: 127

# %%
#computing the list of reviewers/authors wo have reviewed Tangled
print("The full list of authors who have seen and reviewed: " + favorite_movie + " is: ")
print(authors)
# Out:
# The full list of authors who have seen and reviewed: tangled is:
# ['BlueDevilHawk1', 'Skytreader', 'spirona', 'JonnyFendi', 'kristen58', 'JasonGoalie', 'Supermom4', 'DrNegative', 'Palino007', 'heyitsmegrif4', 'Whalnar', 'Halfwelshman', 'Tranquilbez22', 'jordi', 'movielover64', 'Simpkj1', 'Eilrahc', 'Kidknowitall', 'Kalukalay', 'Rumblebeelove', 'AndrewUltimate', 'dinozgorawrr', 'Malasawas', 'Bullet97', 'Forrestgump1', 'InfamousPrince', 'gm101', 'heybuddymovies', 'zamarren', 'movie2187', 'Gari', 'billruller', 'gamer1', 'Zahara', 'MoeYaz', 'Annoymous1', 'Rox22', 'InspectorJ', 'vini1904', 'reneewallace', 'Jwv', 'Parade', 'Bethzaira', 'goopyGoop', 'grandpajoe6191', 'MizLemon', 'MovieLonely94', 'Ruler101', 'iluvmovies', 'rayray', 'Bikerjames', 'ari5610', 'JonnyTheGreat', 'Grothos', 'tazielin', 'TheQuietGamer', 'NaughtyDog', 'Potter17', 'spielbrick90', 'PurpleUrp', 'MovieCritic', 'TitaniumDragon', 'smijatov', 'Jacob', 'lasttimeisaw', 'libbie65', 'RayzorMoose', 'MrsBBaggins', 'lukechristiansc', 'EpicLadySponge', 'SimpsonFans', 'TVJerry', 'Anim8or', 'BubblegumImp', 'Shiira', 'brewcrewpride', 'PYRiAH', 'NickXoN', 'speno93', 'Pier', 'hellenn', 'hippiechick8ify', 'AKJBourne', 'KendylKlownfish', 'nutterjr', 'trish30', 'CitizenCharlie', 'jessetaylor25', 'lionalio', 'DrMovie', 'zogondragon', 'BamaFalstaff', 'randomdude', 'emjohnson54', 'KennElm', 'Broken_Shirt', 'GleekManiac', 'joelschnick', 'J-Shap', 'j30', 'lordjrs', 'WielderofKnives', 'aaronpaul121', 'Zilcell', 'cameronmorewood', 'worleyjamers', 'SEROJ', 'jeff_reviews', 'mapizarro', 'Iky009', 'GodotIsW8ing4U', 'TangledFan', 'Supersaiyan9000', 'IMAX500', 'thetvreviewman', 'ssyeon5643', 'nicholasbert', 'homer4president', 'MrMovieBuff', 'BasilZero', 'CineAutoctono', 'diegonelli', 'Futuredirector', 'bethanyrobben', 'DavidTejada', 'Daniel17', 'MonkiReviews']

# %%
#computing the average score for Tangled compared to my own score for Tangled 
avg = sum/count
print ("The average score of " + favorite_movie + " is: " + str(avg))
print ("Tangled was rated, compared to the score of Kaoutar: " + str(avg-score_kaoutar))
# Out:
# The average score of tangled is: 8.307086614173228
# Tangled was rated, compared to the score of Kaoutar: -0.1929133858267722

# %%
with open('userreviews.csv', 'r', encoding= 'utf-8-sig') as userreviews:
    List1 = []
    List2 = []
    csv_reader = csv.reader(userreviews, delimiter=';')
    for i in csv_reader:
        if (i[2]) in authors and float(i[1]) > float(avg):
            List1.extend([i[0],i[1],i[2]])
            List2.extend([List1])
            print(List1)
            List1 = []
            
            print("Reviewer: " + i[2] + " Score: " + str(i[1]) + " favorite_movie: " + str(i[0]))
# Out:
# ['maudie', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: maudie
# ['baby-driver', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: baby-driver
# ['your-name', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: your-name
# ['the-big-sick', '10', 'kristen58']
# Reviewer: kristen58 Score: 10 favorite_movie: the-big-sick
# ['your-name', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: your-name
# ['war-for-the-planet-of-the-apes', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: war-for-the-planet-of-the-apes
# ['war-for-the-planet-of-the-apes', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: war-for-the-planet-of-the-apes
# ['baby-driver', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: baby-driver
# ['spider-man-homecoming', '10', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 10 favorite_movie: spider-man-homecoming
# ['colossal', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: colossal
# ['norman-the-moderate-rise-and-tragic-fall-of-a-new-york-fixer', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: norman-the-moderate-rise-and-tragic-fall-of-a-new-york-fixer
# ['war-for-the-planet-of-the-apes', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: war-for-the-planet-of-the-apes
# ['baby-driver', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: baby-driver
# ['get-out', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: get-out
# ['baby-driver', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: baby-driver
# ['baby-driver', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: baby-driver
# ['kong-skull-island', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: kong-skull-island
# ['the-lego-batman-movie', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-lego-batman-movie
# ['the-lego-batman-movie', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: the-lego-batman-movie
# ['the-lego-batman-movie', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: the-lego-batman-movie
# ['the-red-turtle', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: the-red-turtle
# ['la-la-land', '10', 'Daniel17']
# Reviewer: Daniel17 Score: 10 favorite_movie: la-la-land
# ['paterson', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: paterson
# ['logan-2017', '10', 'Iky009']
# Reviewer: Iky009 Score: 10 favorite_movie: logan-2017
# ['john-wick-chapter-2', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: john-wick-chapter-2
# ['patriots-day', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: patriots-day
# ['logan-2017', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: logan-2017
# ['get-out', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: get-out
# ['a-monster-calls', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: a-monster-calls
# ['la-la-land', '10', 'SEROJ']
# Reviewer: SEROJ Score: 10 favorite_movie: la-la-land
# ['passengers-2016', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: passengers-2016
# ['hacksaw-ridge', '10', 'SEROJ']
# Reviewer: SEROJ Score: 10 favorite_movie: hacksaw-ridge
# ['get-out', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: get-out
# ['jackie', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: jackie
# ['wonder-woman', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: wonder-woman
# ['wonder-woman', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: wonder-woman
# ['hacksaw-ridge', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: hacksaw-ridge
# ['doctor-strange', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: doctor-strange
# ['loving', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: loving
# ['hacksaw-ridge', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: hacksaw-ridge
# ['moonlight-2016', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: moonlight-2016
# ['deepwater-horizon', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: deepwater-horizon
# ['alien-covenant', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: alien-covenant
# ['the-birth-of-a-nation', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: the-birth-of-a-nation
# ['wonder-woman', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: wonder-woman
# ['moonlight-2016', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: moonlight-2016
# ['arrival', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: arrival
# ['logan-2017', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: logan-2017
# ['hell-or-high-water', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: hell-or-high-water
# ['doctor-strange', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: doctor-strange
# ['wonder-woman', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: wonder-woman
# ['kubo-and-the-two-strings', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: kubo-and-the-two-strings
# ['hell-or-high-water', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: hell-or-high-water
# ['sherpa', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: sherpa
# ['sully', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: sully
# ['hell-or-high-water', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: hell-or-high-water
# ['sully', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: sully
# ['arrival', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: arrival
# ['arrival', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: arrival
# ['kubo-and-the-two-strings', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: kubo-and-the-two-strings
# ['kubo-and-the-two-strings', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: kubo-and-the-two-strings
# ['paths-of-the-soul', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: paths-of-the-soul
# ['jason-bourne', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: jason-bourne
# ['the-shallows', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: the-shallows
# ['warcraft', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: warcraft
# ['april-and-the-extraordinary-world', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: april-and-the-extraordinary-world
# ['the-conjuring-2', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-conjuring-2
# ['sausage-party', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: sausage-party
# ['cemetery-of-splendor', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: cemetery-of-splendor
# ['the-nice-guys', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-nice-guys
# ['green-room', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: green-room
# ['my-golden-days', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: my-golden-days
# ['captain-america-civil-war', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: captain-america-civil-war
# ['the-lobster', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: the-lobster
# ['risen', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: risen
# ['zootopia', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: zootopia
# ['joy', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: joy
# ['zootopia', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: zootopia
# ['captain-america-civil-war', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: captain-america-civil-war
# ['phoenix', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: phoenix
# ['krampus', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: krampus
# ['dirty-grandpa', '9', 'SimpsonFans']
# Reviewer: SimpsonFans Score: 9 favorite_movie: dirty-grandpa
# ['of-men-and-war', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: of-men-and-war
# ['brooklyn', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: brooklyn
# ['the-hunger-games-mockingjay---part-2', '10', 'diegonelli']
# Reviewer: diegonelli Score: 10 favorite_movie: the-hunger-games-mockingjay---part-2
# ['the-hunger-games-mockingjay---part-2', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-hunger-games-mockingjay---part-2
# ['star-wars-episode-vii---the-force-awakens', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['carol', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: carol
# ['spotlight', '10', 'SEROJ']
# Reviewer: SEROJ Score: 10 favorite_movie: spotlight
# ['star-wars-episode-vii---the-force-awakens', '10', 'DavidTejada']
# Reviewer: DavidTejada Score: 10 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['spotlight', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: spotlight
# ['the-diary-of-a-teenage-girl', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: the-diary-of-a-teenage-girl
# ['bridge-of-spies', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: bridge-of-spies
# ['the-good-dinosaur', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-good-dinosaur
# ['captain-america-civil-war', '10', 'homer4president']
# Reviewer: homer4president Score: 10 favorite_movie: captain-america-civil-war
# ['ghostbusters-2016', '10', 'SimpsonFans']
# Reviewer: SimpsonFans Score: 10 favorite_movie: ghostbusters-2016
# ['captain-america-civil-war', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: captain-america-civil-war
# ['bridge-of-spies', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: bridge-of-spies
# ['pan', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: pan
# ['the-visit-2015', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-visit-2015
# ['the-walk', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-walk
# ['captain-america-civil-war', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: captain-america-civil-war
# ['star-wars-episode-vii---the-force-awakens', '10', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 10 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['american-ultra', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: american-ultra
# ['vacation-2015', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: vacation-2015
# ['inside-out-2015', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: inside-out-2015
# ['inside-out-2015', '10', 'diegonelli']
# Reviewer: diegonelli Score: 10 favorite_movie: inside-out-2015
# ['inside-out-2015', '10', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 10 favorite_movie: inside-out-2015
# ['creep', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: creep
# ['vacation-2015', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: vacation-2015
# ['manglehorn', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: manglehorn
# ['insidious-chapter-3', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: insidious-chapter-3
# ['sicario', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: sicario
# ['tomorrowland', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: tomorrowland
# ['the-overnight', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: the-overnight
# ['san-andreas', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: san-andreas
# ['inside-out-2015', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: inside-out-2015
# ['cinderella', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: cinderella
# ['two-days-one-night', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: two-days-one-night
# ['two-days-one-night', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: two-days-one-night
# ['inside-out-2015', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: inside-out-2015
# ['71', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: 71
# ['inside-out-2015', '9', 'Annoymous1']
# Reviewer: Annoymous1 Score: 9 favorite_movie: inside-out-2015
# ['furious-7', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: furious-7
# ['get-hard', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: get-hard
# ['mad-max-fury-road', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: mad-max-fury-road
# ['ex-machina', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: ex-machina
# ['inside-out-2015', '10', 'homer4president']
# Reviewer: homer4president Score: 10 favorite_movie: inside-out-2015
# ['focus-2015', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: focus-2015
# ['leviathan-2014', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: leviathan-2014
# ['selma', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: selma
# ['winter-sleep', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: winter-sleep
# ['it-follows', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: it-follows
# ['a-girl-walks-home-alone-at-night', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: a-girl-walks-home-alone-at-night
# ['the-wedding-ringer', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: the-wedding-ringer
# ['the-babadook', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-babadook
# ['goodbye-to-language', '10', 'mapizarro']
# Reviewer: mapizarro Score: 10 favorite_movie: goodbye-to-language
# ['mr-turner', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: mr-turner
# ['inside-out-2015', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: inside-out-2015
# ['ex-machina', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: ex-machina
# ['paddington', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: paddington
# ['the-breakfast-club', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: the-breakfast-club
# ['unbroken', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: unbroken
# ['song-of-the-sea', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: song-of-the-sea
# ['penguins-of-madagascar', '9', 'IMAX500']
# Reviewer: IMAX500 Score: 9 favorite_movie: penguins-of-madagascar
# ['mad-max-fury-road', '9', 'Jacob']
# Reviewer: Jacob Score: 9 favorite_movie: mad-max-fury-road
# ['song-of-the-sea', '9', 'SEROJ']
# Reviewer: SEROJ Score: 9 favorite_movie: song-of-the-sea
# ['inside-out-2015', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: inside-out-2015
# ['selma', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: selma
# ['mad-max-fury-road', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: mad-max-fury-road
# ['unbroken', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: unbroken
# ['into-the-woods', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: into-the-woods
# ['whiplash', '9', 'grandpajoe6191']
# Reviewer: grandpajoe6191 Score: 9 favorite_movie: whiplash
# ['foxcatcher', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: foxcatcher
# ['mad-max-fury-road', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: mad-max-fury-road
# ['the-theory-of-everything', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: the-theory-of-everything
# ['big-hero-6', '10', 'IMAX500']
# Reviewer: IMAX500 Score: 10 favorite_movie: big-hero-6
# ['big-hero-6', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: big-hero-6
# ['21-years-richard-linklater', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: 21-years-richard-linklater
# ['the-hunger-games-mockingjay---part-1', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-hunger-games-mockingjay---part-1
# ['honeymoon', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: honeymoon
# ['whiplash', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: whiplash
# ['the-theory-of-everything', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: the-theory-of-everything
# ['the-hobbit-the-battle-of-the-five-armies', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: the-hobbit-the-battle-of-the-five-armies
# ['big-hero-6', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: big-hero-6
# ['get-on-up', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: get-on-up
# ['horns', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: horns
# ['gone-girl', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: gone-girl
# ['the-interview', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-interview
# ['big-hero-6', '9', 'Daniel17']
# Reviewer: Daniel17 Score: 9 favorite_movie: big-hero-6
# ['the-hunger-games-mockingjay---part-1', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-hunger-games-mockingjay---part-1
# ['big-hero-6', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: big-hero-6
# ['big-hero-6', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: big-hero-6
# ['how-to-train-your-dragon-2', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: how-to-train-your-dragon-2
# ['the-wind-rises', '10', 'Iky009']
# Reviewer: Iky009 Score: 10 favorite_movie: the-wind-rises
# ['big-hero-6', '10', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 10 favorite_movie: big-hero-6
# ['the-wind-rises', '9', 'mapizarro']
# Reviewer: mapizarro Score: 9 favorite_movie: the-wind-rises
# ['mad-max-fury-road', '10', 'Bikerjames']
# Reviewer: Bikerjames Score: 10 favorite_movie: mad-max-fury-road
# ['jersey-boys', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: jersey-boys
# ['whiplash', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: whiplash
# ['the-wind-rises', '9', 'grandpajoe6191']
# Reviewer: grandpajoe6191 Score: 9 favorite_movie: the-wind-rises
# ['how-to-train-your-dragon-2', '10', 'IMAX500']
# Reviewer: IMAX500 Score: 10 favorite_movie: how-to-train-your-dragon-2
# ['how-to-train-your-dragon-2', '10', 'Bikerjames']
# Reviewer: Bikerjames Score: 10 favorite_movie: how-to-train-your-dragon-2
# ['dawn-of-the-planet-of-the-apes', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: dawn-of-the-planet-of-the-apes
# ['how-to-train-your-dragon-2', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: how-to-train-your-dragon-2
# ['dawn-of-the-planet-of-the-apes', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: dawn-of-the-planet-of-the-apes
# ['gone-girl', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: gone-girl
# ['dawn-of-the-planet-of-the-apes', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: dawn-of-the-planet-of-the-apes
# ['neighbors', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: neighbors
# ['the-fault-in-our-stars', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: the-fault-in-our-stars
# ['the-fault-in-our-stars', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-fault-in-our-stars
# ['ida', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: ida
# ['a-million-ways-to-die-in-the-west', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: a-million-ways-to-die-in-the-west
# ['filth', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: filth
# ['blue-ruin', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: blue-ruin
# ['the-face-of-love', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-face-of-love
# ['under-the-skin', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: under-the-skin
# ['heaven-is-for-real', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: heaven-is-for-real
# ['rio-2', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: rio-2
# ['oculus', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: oculus
# ['the-missing-picture', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: the-missing-picture
# ['non-stop-2014', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: non-stop-2014
# ['x-men-days-of-future-past', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: x-men-days-of-future-past
# ['the-lego-movie', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: the-lego-movie
# ['x-men-days-of-future-past', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: x-men-days-of-future-past
# ['mad-max-fury-road', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: mad-max-fury-road
# ['about-last-night', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: about-last-night
# ['jack-ryan-shadow-recruit', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: jack-ryan-shadow-recruit
# ['the-lego-movie', '10', 'Annoymous1']
# Reviewer: Annoymous1 Score: 10 favorite_movie: the-lego-movie
# ['pompeii', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: pompeii
# ['mad-max-fury-road', '10', 'Iky009']
# Reviewer: Iky009 Score: 10 favorite_movie: mad-max-fury-road
# ['the-grand-budapest-hotel', '10', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 10 favorite_movie: the-grand-budapest-hotel
# ['300-rise-of-an-empire', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: 300-rise-of-an-empire
# ['lone-survivor', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: lone-survivor
# ['noah', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: noah
# ['philomena', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: philomena
# ['philomena', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: philomena
# ['the-monuments-men', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-monuments-men
# ['x-men-days-of-future-past', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: x-men-days-of-future-past
# ['philomena', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: philomena
# ['godzilla-2014', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: godzilla-2014
# ['august-osage-county', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: august-osage-county
# ['the-broken-circle-breakdown', '10', 'nutterjr']
# Reviewer: nutterjr Score: 10 favorite_movie: the-broken-circle-breakdown
# ['the-great-beauty', '9', 'nicholasbert']
# Reviewer: nicholasbert Score: 9 favorite_movie: the-great-beauty
# ['x-men-days-of-future-past', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: x-men-days-of-future-past
# ['august-osage-county', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: august-osage-county
# ['the-grand-budapest-hotel', '9', 'Jacob']
# Reviewer: Jacob Score: 9 favorite_movie: the-grand-budapest-hotel
# ['the-grand-budapest-hotel', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: the-grand-budapest-hotel
# ['the-lego-movie', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: the-lego-movie
# ['the-wolf-of-wall-street', '9', 'grandpajoe6191']
# Reviewer: grandpajoe6191 Score: 9 favorite_movie: the-wolf-of-wall-street
# ['the-lego-movie', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: the-lego-movie
# ['frozen-2013', '9', 'thetvreviewman']
# Reviewer: thetvreviewman Score: 9 favorite_movie: frozen-2013
# ['saving-mr-banks', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: saving-mr-banks
# ['american-hustle', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: american-hustle
# ['frozen-2013', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: frozen-2013
# ['frozen-2013', '9', 'bethanyrobben']
# Reviewer: bethanyrobben Score: 9 favorite_movie: frozen-2013
# ['inside-llewyn-davis', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: inside-llewyn-davis
# ['the-lego-movie', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: the-lego-movie
# ['the-lego-movie', '10', 'IMAX500']
# Reviewer: IMAX500 Score: 10 favorite_movie: the-lego-movie
# ['frozen-2013', '10', 'Parade']
# Reviewer: Parade Score: 10 favorite_movie: frozen-2013
# ['the-secret-life-of-walter-mitty', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-secret-life-of-walter-mitty
# ['all-is-lost', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: all-is-lost
# ['saving-mr-banks', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: saving-mr-banks
# ['godzilla-2014', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: godzilla-2014
# ['frozen-2013', '10', 'DrNegative']
# Reviewer: DrNegative Score: 10 favorite_movie: frozen-2013
# ['the-wolf-of-wall-street', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: the-wolf-of-wall-street
# ['all-is-lost', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: all-is-lost
# ['the-lego-movie', '9', 'kristen58']
# Reviewer: kristen58 Score: 9 favorite_movie: the-lego-movie
# ['frozen-2013', '9', 'mapizarro']
# Reviewer: mapizarro Score: 9 favorite_movie: frozen-2013
# ['escape-plan', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: escape-plan
# ['the-secret-life-of-walter-mitty', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: the-secret-life-of-walter-mitty
# ['jackass-presents-bad-grandpa', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: jackass-presents-bad-grandpa
# ['anchorman-2-the-legend-continues', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: anchorman-2-the-legend-continues
# ['godzilla-2014', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: godzilla-2014
# ['anchorman-2-the-legend-continues', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: anchorman-2-the-legend-continues
# ['frozen-2013', '10', 'reneewallace']
# Reviewer: reneewallace Score: 10 favorite_movie: frozen-2013
# ['riddick', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: riddick
# ['inside-llewyn-davis', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: inside-llewyn-davis
# ['20-feet-from-stardom', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: 20-feet-from-stardom
# ['dallas-buyers-club', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: dallas-buyers-club
# ['the-spectacular-now', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: the-spectacular-now
# ['enough-said', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: enough-said
# ['the-hobbit-the-desolation-of-smaug', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-hobbit-the-desolation-of-smaug
# ['the-spectacular-now', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-spectacular-now
# ['lee-daniels-the-butler', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: lee-daniels-the-butler
# ['the-hunt', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: the-hunt
# ['fast-furious-6', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: fast-furious-6
# ['fast-furious-6', '9', 'Zilcell']
# Reviewer: Zilcell Score: 9 favorite_movie: fast-furious-6
# ['the-hunt', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: the-hunt
# ['the-hunt', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: the-hunt
# ['wolf-children', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: wolf-children
# ['the-lego-movie', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: the-lego-movie
# ['wolf-children', '9', 'SEROJ']
# Reviewer: SEROJ Score: 9 favorite_movie: wolf-children
# ['american-hustle', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: american-hustle
# ['prisoners', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: prisoners
# ['red-2', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: red-2
# ['frances-ha', '9', 'Shiira']
# Reviewer: Shiira Score: 9 favorite_movie: frances-ha
# ['girl-most-likely', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: girl-most-likely
# ['prisoners', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: prisoners
# ['despicable-me-2', '9', 'Rox22']
# Reviewer: Rox22 Score: 9 favorite_movie: despicable-me-2
# ['turbo', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: turbo
# ['barbara', '10', 'Bikerjames']
# Reviewer: Bikerjames Score: 10 favorite_movie: barbara
# ['parkland', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: parkland
# ['a-hijacking', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: a-hijacking
# ['kevin-hart-let-me-explain', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: kevin-hart-let-me-explain
# ['despicable-me-2', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: despicable-me-2
# ['frozen-2013', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: frozen-2013
# ['the-wolf-of-wall-street', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: the-wolf-of-wall-street
# ['fast-furious-6', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: fast-furious-6
# ['the-croods', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: the-croods
# ['the-croods', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-croods
# ['the-croods', '9', 'Zilcell']
# Reviewer: Zilcell Score: 9 favorite_movie: the-croods
# ['frozen-2013', '10', 'BasilZero']
# Reviewer: BasilZero Score: 10 favorite_movie: frozen-2013
# ['after-earth', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: after-earth
# ['from-up-on-poppy-hill', '10', 'mapizarro']
# Reviewer: mapizarro Score: 10 favorite_movie: from-up-on-poppy-hill
# ['war-witch', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: war-witch
# ['frozen-2013', '9', 'Daniel17']
# Reviewer: Daniel17 Score: 9 favorite_movie: frozen-2013
# ['blancanieves', '9', 'mapizarro']
# Reviewer: mapizarro Score: 9 favorite_movie: blancanieves
# ['from-up-on-poppy-hill', '9', 'jeff_reviews']
# Reviewer: jeff_reviews Score: 9 favorite_movie: from-up-on-poppy-hill
# ['frozen-2013', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: frozen-2013
# ['the-wolverine', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-wolverine
# ['man-of-steel', '9', 'Rox22']
# Reviewer: Rox22 Score: 9 favorite_movie: man-of-steel
# ['now-you-see-me', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: now-you-see-me
# ['the-reluctant-fundamentalist', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: the-reluctant-fundamentalist
# ['amour', '10', 'nutterjr']
# Reviewer: nutterjr Score: 10 favorite_movie: amour
# ['now-you-see-me', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: now-you-see-me
# ['world-war-z', '10', 'Parade']
# Reviewer: Parade Score: 10 favorite_movie: world-war-z
# ['now-you-see-me', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: now-you-see-me
# ['the-purge', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-purge
# ['the-place-beyond-the-pines', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: the-place-beyond-the-pines
# ['amour', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: amour
# ['the-place-beyond-the-pines', '9', 'worleyjamers']
# Reviewer: worleyjamers Score: 9 favorite_movie: the-place-beyond-the-pines
# ['the-gatekeepers', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: the-gatekeepers
# ['olympus-has-fallen', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: olympus-has-fallen
# ['the-call', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: the-call
# ['olympus-has-fallen', '10', 'Zilcell']
# Reviewer: Zilcell Score: 10 favorite_movie: olympus-has-fallen
# ['spring-breakers', '9', 'Shiira']
# Reviewer: Shiira Score: 9 favorite_movie: spring-breakers
# ['the-call', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-call
# ['the-wolverine', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: the-wolverine
# ['hansel-and-gretel-witch-hunters', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: hansel-and-gretel-witch-hunters
# ['spring-breakers', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: spring-breakers
# ['the-last-exorcism-part-ii', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-last-exorcism-part-ii
# ['42', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: 42
# ['the-call', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-call
# ['cloud-atlas', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: cloud-atlas
# ['42', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: 42
# ['side-effects-2013', '9', 'worleyjamers']
# Reviewer: worleyjamers Score: 9 favorite_movie: side-effects-2013
# ['movie-43', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: movie-43
# ['side-effects-2013', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: side-effects-2013
# ['texas-chainsaw-3d', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: texas-chainsaw-3d
# ['django-unchained', '10', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 10 favorite_movie: django-unchained
# ['the-impossible', '9', 'jordi']
# Reviewer: jordi Score: 9 favorite_movie: the-impossible
# ['the-impossible', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: the-impossible
# ['jack-reacher', '10', 'Zilcell']
# Reviewer: Zilcell Score: 10 favorite_movie: jack-reacher
# ['django-unchained', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: django-unchained
# ['world-war-z', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: world-war-z
# ['jack-reacher', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: jack-reacher
# ['the-great-gatsby', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-great-gatsby
# ['a-haunted-house', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: a-haunted-house
# ['django-unchained', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: django-unchained
# ['silver-linings-playbook', '9', 'Shiira']
# Reviewer: Shiira Score: 9 favorite_movie: silver-linings-playbook
# ['lincoln', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: lincoln
# ['waiting-for-lightning', '10', 'SimpsonFans']
# Reviewer: SimpsonFans Score: 10 favorite_movie: waiting-for-lightning
# ['argo', '10', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 10 favorite_movie: argo
# ['les-miserables', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: les-miserables
# ['les-miserables', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: les-miserables
# ['lincoln', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: lincoln
# ['silver-linings-playbook', '10', 'Bikerjames']
# Reviewer: Bikerjames Score: 10 favorite_movie: silver-linings-playbook
# ['the-twilight-saga-breaking-dawn---part-2', '9', 'jordi']
# Reviewer: jordi Score: 9 favorite_movie: the-twilight-saga-breaking-dawn---part-2
# ['side-by-side', '9', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 9 favorite_movie: side-by-side
# ['silver-linings-playbook', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: silver-linings-playbook
# ['argo', '10', 'smijatov']
# Reviewer: smijatov Score: 10 favorite_movie: argo
# ['celeste-and-jesse-forever', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: celeste-and-jesse-forever
# ['argo', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: argo
# ['silver-linings-playbook', '9', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 9 favorite_movie: silver-linings-playbook
# ['this-is-40', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: this-is-40
# ['flight', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: flight
# ['silver-linings-playbook', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: silver-linings-playbook
# ['world-war-z', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: world-war-z
# ['seven-psychopaths', '9', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 9 favorite_movie: seven-psychopaths
# ['hotel-transylvania', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: hotel-transylvania
# ['argo', '9', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 9 favorite_movie: argo
# ['the-master', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: the-master
# ['django-unchained', '9', 'grandpajoe6191']
# Reviewer: grandpajoe6191 Score: 9 favorite_movie: django-unchained
# ['silver-linings-playbook', '10', 'worleyjamers']
# Reviewer: worleyjamers Score: 10 favorite_movie: silver-linings-playbook
# ['django-unchained', '10', 'Zilcell']
# Reviewer: Zilcell Score: 10 favorite_movie: django-unchained
# ['les-miserables', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: les-miserables
# ['brave', '10', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 10 favorite_movie: brave
# ['lincoln', '9', 'worleyjamers']
# Reviewer: worleyjamers Score: 9 favorite_movie: lincoln
# ['arthur-christmas', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: arthur-christmas
# ['arthur-christmas', '9', 'Halfwelshman']
# Reviewer: Halfwelshman Score: 9 favorite_movie: arthur-christmas
# ['les-miserables', '10', 'InspectorJ']
# Reviewer: InspectorJ Score: 10 favorite_movie: les-miserables
# ['flight', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: flight
# ['paranorman', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: paranorman
# ['les-miserables', '9', 'jordi']
# Reviewer: jordi Score: 9 favorite_movie: les-miserables
# ['men-in-black-iii', '9', 'Zilcell']
# Reviewer: Zilcell Score: 9 favorite_movie: men-in-black-iii
# ['lawless', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: lawless
# ['the-master', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: the-master
# ['argo', '9', 'jordi']
# Reviewer: jordi Score: 9 favorite_movie: argo
# ['brave', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: brave
# ['the-master', '10', 'j30']
# Reviewer: j30 Score: 10 favorite_movie: the-master
# ['django-unchained', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: django-unchained
# ['the-master', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: the-master
# ['silver-linings-playbook', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: silver-linings-playbook
# ['lincoln', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: lincoln
# ['men-in-black-iii', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: men-in-black-iii
# ['django-unchained', '9', 'worleyjamers']
# Reviewer: worleyjamers Score: 9 favorite_movie: django-unchained
# ['safe', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: safe
# ['sound-of-my-voice', '9', 'Shiira']
# Reviewer: Shiira Score: 9 favorite_movie: sound-of-my-voice
# ['the-cabin-in-the-woods', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: the-cabin-in-the-woods
# ['the-avengers-2012', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-avengers-2012
# ['the-expendables-2', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-expendables-2
# ['argo', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: argo
# ['argo', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: argo
# ['dr-seuss-the-lorax', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: dr-seuss-the-lorax
# ['the-avengers-2012', '9', 'worleyjamers']
# Reviewer: worleyjamers Score: 9 favorite_movie: the-avengers-2012
# ['the-avengers-2012', '10', 'jeff_reviews']
# Reviewer: jeff_reviews Score: 10 favorite_movie: the-avengers-2012
# ['the-cabin-in-the-woods', '10', 'TitaniumDragon']
# Reviewer: TitaniumDragon Score: 10 favorite_movie: the-cabin-in-the-woods
# ['bernie', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: bernie
# ['the-expendables-2', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-expendables-2
# ['a-separation', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: a-separation
# ['the-artist', '9', 'grandpajoe6191']
# Reviewer: grandpajoe6191 Score: 9 favorite_movie: the-artist
# ['bernie', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: bernie
# ['a-separation', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: a-separation
# ['the-artist', '10', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 10 favorite_movie: the-artist
# ['the-artist', '10', 'CitizenCharlie']
# Reviewer: CitizenCharlie Score: 10 favorite_movie: the-artist
# ['jeff-who-lives-at-home', '9', 'Shiira']
# Reviewer: Shiira Score: 9 favorite_movie: jeff-who-lives-at-home
# ['a-separation', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: a-separation
# ['the-three-stooges', '9', 'Zilcell']
# Reviewer: Zilcell Score: 9 favorite_movie: the-three-stooges
# ['the-avengers-2012', '10', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 10 favorite_movie: the-avengers-2012
# ['dr-seuss-the-lorax', '10', 'MrsBBaggins']
# Reviewer: MrsBBaggins Score: 10 favorite_movie: dr-seuss-the-lorax
# ['a-separation', '10', 'worleyjamers']
# Reviewer: worleyjamers Score: 10 favorite_movie: a-separation
# ['the-artist', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: the-artist
# ['american-reunion', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: american-reunion
# ['the-amazing-spider-man', '9', 'Zilcell']
# Reviewer: Zilcell Score: 9 favorite_movie: the-amazing-spider-man
# ['the-artist', '9', 'JonnyFendi']
# Reviewer: JonnyFendi Score: 9 favorite_movie: the-artist
# ['a-separation', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: a-separation
# ['the-artist', '10', 'j30']
# Reviewer: j30 Score: 10 favorite_movie: the-artist
# ['21-jump-street', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: 21-jump-street
# ['django-unchained', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: django-unchained
# ['21-jump-street', '10', 'Zilcell']
# Reviewer: Zilcell Score: 10 favorite_movie: 21-jump-street
# ['21-jump-street', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: 21-jump-street
# ['project-x', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: project-x
# ['joyful-noise', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: joyful-noise
# ['the-artist', '9', 'aaronpaul121']
# Reviewer: aaronpaul121 Score: 9 favorite_movie: the-artist
# ['the-artist', '9', 'Halfwelshman']
# Reviewer: Halfwelshman Score: 9 favorite_movie: the-artist
# ['project-x', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: project-x
# ['the-avengers-2012', '10', 'billruller']
# Reviewer: billruller Score: 10 favorite_movie: the-avengers-2012
# ['the-avengers-2012', '10', 'Tranquilbez22']
# Reviewer: Tranquilbez22 Score: 10 favorite_movie: the-avengers-2012
# ['the-muppets', '10', 'kristen58']
# Reviewer: kristen58 Score: 10 favorite_movie: the-muppets
# ['the-muppets', '10', 'Tranquilbez22']
# Reviewer: Tranquilbez22 Score: 10 favorite_movie: the-muppets
# ['the-descendants', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: the-descendants
# ['the-muppets', '10', 'gm101']
# Reviewer: gm101 Score: 10 favorite_movie: the-muppets
# ['the-muppets', '9', 'Rumblebeelove']
# Reviewer: Rumblebeelove Score: 9 favorite_movie: the-muppets
# ['the-adventures-of-tintin', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-adventures-of-tintin
# ['the-grey', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-grey
# ['the-sitter', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-sitter
# ['the-artist', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: the-artist
# ['we-bought-a-zoo', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: we-bought-a-zoo
# ['the-girl-with-the-dragon-tattoo-2011', '9', 'worleyjamers']
# Reviewer: worleyjamers Score: 9 favorite_movie: the-girl-with-the-dragon-tattoo-2011
# ['the-girl-with-the-dragon-tattoo-2011', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-girl-with-the-dragon-tattoo-2011
# ['the-artist', '10', 'worleyjamers']
# Reviewer: worleyjamers Score: 10 favorite_movie: the-artist
# ['the-descendants', '10', 'Shiira']
# Reviewer: Shiira Score: 10 favorite_movie: the-descendants
# ['the-adventures-of-tintin', '9', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 9 favorite_movie: the-adventures-of-tintin
# ['the-grey', '10', 'Zilcell']
# Reviewer: Zilcell Score: 10 favorite_movie: the-grey
# ['the-cabin-in-the-woods', '9', 'Rox22']
# Reviewer: Rox22 Score: 9 favorite_movie: the-cabin-in-the-woods
# ['the-descendants', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: the-descendants
# ['the-muppets', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: the-muppets
# ['the-muppets', '10', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 10 favorite_movie: the-muppets
# ['the-descendants', '9', 'Halfwelshman']
# Reviewer: Halfwelshman Score: 9 favorite_movie: the-descendants
# ['tinker-tailor-soldier-spy', '10', 'Halfwelshman']
# Reviewer: Halfwelshman Score: 10 favorite_movie: tinker-tailor-soldier-spy
# ['the-hunger-games', '10', 'heyitsmegrif4']
# Reviewer: heyitsmegrif4 Score: 10 favorite_movie: the-hunger-games
# ['shame', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: shame
# ['war-horse', '9', 'movie2187']
# Reviewer: movie2187 Score: 9 favorite_movie: war-horse
# ['21-jump-street', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: 21-jump-street
# ['shame', '10', 'cameronmorewood']
# Reviewer: cameronmorewood Score: 10 favorite_movie: shame
# ['mission-impossible---ghost-protocol', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: mission-impossible---ghost-protocol
# ['the-skin-i-live-in', '9', 'Shiira']
# Reviewer: Shiira Score: 9 favorite_movie: the-skin-i-live-in
# ['j-edgar', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: j-edgar
# ['puss-in-boots', '10', 'PurpleUrp']
# ...
# Reviewer: worleyjamers Score: 10 favorite_movie: avatar
# ['the-dark-knight-rises', '9', 'lionalio']
# Reviewer: lionalio Score: 9 favorite_movie: the-dark-knight-rises
# ['the-dark-knight-rises', '10', 'spielbrick90']
# Reviewer: spielbrick90 Score: 10 favorite_movie: the-dark-knight-rises
# ['12-years-a-slave', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: 12-years-a-slave
# ['avatar', '10', 'SEROJ']
# Reviewer: SEROJ Score: 10 favorite_movie: avatar
# ['12-years-a-slave', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: 12-years-a-slave
# ['housebound', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: housebound
# ['avatar', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: avatar
# ['divergent', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: divergent
# ['captain-america-the-winter-soldier', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: captain-america-the-winter-soldier
# ['her', '9', 'Jacob']
# Reviewer: Jacob Score: 9 favorite_movie: her
# ['as-above-so-below', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: as-above-so-below
# ['her', '10', 'Iky009']
# Reviewer: Iky009 Score: 10 favorite_movie: her
# ['captain-america-the-winter-soldier', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: captain-america-the-winter-soldier
# ['22-jump-street', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: 22-jump-street
# ['her', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: her
# ['the-hunger-games-catching-fire', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: the-hunger-games-catching-fire
# ['a-walk-among-the-tombstones', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: a-walk-among-the-tombstones
# ['the-amazing-spider-man-2', '10', 'Annoymous1']
# Reviewer: Annoymous1 Score: 10 favorite_movie: the-amazing-spider-man-2
# ['the-overnighters', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: the-overnighters
# ['the-amazing-spider-man-2', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-amazing-spider-man-2
# ['gravity', '10', 'mapizarro']
# Reviewer: mapizarro Score: 10 favorite_movie: gravity
# ['her', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: her
# ['hector-and-the-search-for-happiness', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: hector-and-the-search-for-happiness
# ['the-dark-knight-rises', '9', 'Daniel17']
# Reviewer: Daniel17 Score: 9 favorite_movie: the-dark-knight-rises
# ['alexander-and-the-terrible-horrible-no-good-very-bad-day', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: alexander-and-the-terrible-horrible-no-good-very-bad-day
# ['the-dark-knight-rises', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: the-dark-knight-rises
# ['nightcrawler', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: nightcrawler
# ['captain-america-the-winter-soldier', '9', 'Forrestgump1']
# Reviewer: Forrestgump1 Score: 9 favorite_movie: captain-america-the-winter-soldier
# ['john-wick', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: john-wick
# ['st-vincent', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: st-vincent
# ['the-amazing-spider-man-2', '9', 'BasilZero']
# Reviewer: BasilZero Score: 9 favorite_movie: the-amazing-spider-man-2
# ['life-itself', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: life-itself
# ['life-itself', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: life-itself
# ['john-wick', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: john-wick
# ['gravity', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: gravity
# ['gravity', '9', 'Bikerjames']
# Reviewer: Bikerjames Score: 9 favorite_movie: gravity
# ['nightcrawler', '9', 'Shiira']
# Reviewer: Shiira Score: 9 favorite_movie: nightcrawler
# ['nightcrawler', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: nightcrawler
# ['boyhood', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: boyhood
# ['wild', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: wild
# ['the-imitation-game', '10', 'InspectorJ']
# Reviewer: InspectorJ Score: 10 favorite_movie: the-imitation-game
# ['the-imitation-game', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: the-imitation-game
# ['interstellar', '10', 'Iky009']
# Reviewer: Iky009 Score: 10 favorite_movie: interstellar
# ['guardians-of-the-galaxy', '10', 'kristen58']
# Reviewer: kristen58 Score: 10 favorite_movie: guardians-of-the-galaxy
# ['captain-america-the-winter-soldier', '10', 'IMAX500']
# Reviewer: IMAX500 Score: 10 favorite_movie: captain-america-the-winter-soldier
# ['the-loft', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: the-loft
# ['gett-the-trial-of-viviane-amsalem', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: gett-the-trial-of-viviane-amsalem
# ['interstellar', '10', 'Parade']
# Reviewer: Parade Score: 10 favorite_movie: interstellar
# ['guardians-of-the-galaxy', '10', 'SEROJ']
# Reviewer: SEROJ Score: 10 favorite_movie: guardians-of-the-galaxy
# ['timbuktu', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: timbuktu
# ['wild-tales', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: wild-tales
# ['american-sniper', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: american-sniper
# ['american-sniper', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: american-sniper
# ['run-all-night', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: run-all-night
# ['guardians-of-the-galaxy', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: guardians-of-the-galaxy
# ['guardians-of-the-galaxy', '10', 'IMAX500']
# Reviewer: IMAX500 Score: 10 favorite_movie: guardians-of-the-galaxy
# ['interstellar', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: interstellar
# ['boyhood', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: boyhood
# ['man-on-fire', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: man-on-fire
# ['fifty-shades-of-grey', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: fifty-shades-of-grey
# ['captain-america-the-winter-soldier', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: captain-america-the-winter-soldier
# ['love-mercy', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: love-mercy
# ['spy', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: spy
# ['gravity', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: gravity
# ['guardians-of-the-galaxy', '10', 'BasilZero']
# Reviewer: BasilZero Score: 10 favorite_movie: guardians-of-the-galaxy
# ['gravity', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: gravity
# ['chappie', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: chappie
# ['what-we-did-on-our-holiday', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: what-we-did-on-our-holiday
# ['interstellar', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: interstellar
# ['when-marnie-was-there', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: when-marnie-was-there
# ['dope', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: dope
# ['gravity', '9', 'InspectorJ']
# Reviewer: InspectorJ Score: 9 favorite_movie: gravity
# ['kingsman-the-secret-service', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: kingsman-the-secret-service
# ['american-sniper', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: american-sniper
# ['paper-towns', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: paper-towns
# ['rio', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: rio
# ['kingsman-the-secret-service', '9', 'lasttimeisaw']
# Reviewer: lasttimeisaw Score: 9 favorite_movie: kingsman-the-secret-service
# ['rio', '9', 'InspectorJ']
# Reviewer: InspectorJ Score: 9 favorite_movie: rio
# ['spy', '9', 'DavidTejada']
# Reviewer: DavidTejada Score: 9 favorite_movie: spy
# ['trainwreck', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: trainwreck
# ['amy-2015', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: amy-2015
# ['star-wars-episode-vii---the-force-awakens', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['star-wars-episode-vii---the-force-awakens', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['amy-2015', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: amy-2015
# ['the-look-of-silence', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: the-look-of-silence
# ['gravity', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: gravity
# ['gravity', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: gravity
# ['guardians-of-the-galaxy', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: guardians-of-the-galaxy
# ['steve-jobs', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: steve-jobs
# ['hotel-transylvania-2', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: hotel-transylvania-2
# ['maze-runner-the-scorch-trials', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: maze-runner-the-scorch-trials
# ['hotel-transylvania-2', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: hotel-transylvania-2
# ['guardians-of-the-galaxy', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: guardians-of-the-galaxy
# ['zootopia', '9', 'Jacob']
# Reviewer: Jacob Score: 9 favorite_movie: zootopia
# ['room-2015', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: room-2015
# ['miss-you-already', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: miss-you-already
# ['zootopia', '9', 'homer4president']
# Reviewer: homer4president Score: 9 favorite_movie: zootopia
# ['ant-man', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: ant-man
# ['crimson-peak', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: crimson-peak
# ['steve-jobs', '10', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 10 favorite_movie: steve-jobs
# ['jafar-panahis-taxi', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: jafar-panahis-taxi
# ['crimson-peak', '9', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 9 favorite_movie: crimson-peak
# ['zootopia', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: zootopia
# ['the-danish-girl', '10', 'lukechristiansc']
# Reviewer: lukechristiansc Score: 10 favorite_movie: the-danish-girl
# ['the-martian', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-martian
# ['interstellar', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: interstellar
# ['jurassic-world', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: jurassic-world
# ['zootopia', '9', 'MrMovieBuff']
# Reviewer: MrMovieBuff Score: 9 favorite_movie: zootopia
# ['mission-impossible---rogue-nation', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: mission-impossible---rogue-nation
# ['the-revenant-2015', '9', 'Iky009']
# Reviewer: Iky009 Score: 9 favorite_movie: the-revenant-2015
# ['mustang', '9', 'nutterjr']
# Reviewer: nutterjr Score: 9 favorite_movie: mustang
# ['zootopia', '10', 'Daniel17']
# Reviewer: Daniel17 Score: 10 favorite_movie: zootopia
# ['zootopia', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: zootopia
# ['zootopia', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: zootopia
# ['creed', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: creed
# ['the-martian', '9', 'SEROJ']
# Reviewer: SEROJ Score: 9 favorite_movie: the-martian
# ['star-wars-episode-vii---the-force-awakens', '9', 'SimpsonFans']
# Reviewer: SimpsonFans Score: 9 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['interstellar', '9', 'BasilZero']
# Reviewer: BasilZero Score: 9 favorite_movie: interstellar
# ['the-revenant-2015', '10', 'SEROJ']
# Reviewer: SEROJ Score: 10 favorite_movie: the-revenant-2015
# ['popstar-never-stop-never-stopping', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: popstar-never-stop-never-stopping
# ['the-purge-election-year', '10', 'SimpsonFans']
# Reviewer: SimpsonFans Score: 10 favorite_movie: the-purge-election-year
# ['the-purge-election-year', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-purge-election-year
# ['the-jungle-book-2016', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: the-jungle-book-2016
# ['the-jungle-book-2016', '9', 'BasilZero']
# Reviewer: BasilZero Score: 9 favorite_movie: the-jungle-book-2016
# ['the-bfg', '10', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 10 favorite_movie: the-bfg
# ['the-revenant-2015', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: the-revenant-2015
# ['petes-dragon', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: petes-dragon
# ['la-la-land', '9', 'CineAutoctono']
# Reviewer: CineAutoctono Score: 9 favorite_movie: la-la-land
# ['guardians-of-the-galaxy-vol-2', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: guardians-of-the-galaxy-vol-2
# ['la-la-land', '9', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 9 favorite_movie: la-la-land
# ['la-la-land', '10', 'Futuredirector']
# Reviewer: Futuredirector Score: 10 favorite_movie: la-la-land
# ['finding-dory', '10', 'EpicLadySponge']
# Reviewer: EpicLadySponge Score: 10 favorite_movie: finding-dory
# ['la-la-land', '10', 'Jacob']
# Reviewer: Jacob Score: 10 favorite_movie: la-la-land
# ['jurassic-world', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: jurassic-world
# ['interstellar', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: interstellar
# ['lion', '9', 'kristen58']
# Reviewer: kristen58 Score: 9 favorite_movie: lion
# ['manchester-by-the-sea', '10', 'nutterjr']
# Reviewer: nutterjr Score: 10 favorite_movie: manchester-by-the-sea
# ['finding-dory', '10', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 10 favorite_movie: finding-dory
# ['beauty-and-the-beast-2017', '9', 'diegonelli']
# Reviewer: diegonelli Score: 9 favorite_movie: beauty-and-the-beast-2017
# ['lion', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: lion
# ['manchester-by-the-sea', '9', 'TVJerry']
# Reviewer: TVJerry Score: 9 favorite_movie: manchester-by-the-sea
# ['raw', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: raw
# ['hidden-figures', '9', 'Futuredirector']
# Reviewer: Futuredirector Score: 9 favorite_movie: hidden-figures
# ['hidden-figures', '9', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 9 favorite_movie: hidden-figures
# ['x-men-apocalypse', '10', 'SimpsonFans']
# Reviewer: SimpsonFans Score: 10 favorite_movie: x-men-apocalypse
# ['deadpool', '10', 'TVJerry']
# Reviewer: TVJerry Score: 10 favorite_movie: deadpool
# ['deadpool', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: deadpool
# ['star-wars-episode-vii---the-force-awakens', '9', 'Jacob']
# Reviewer: Jacob Score: 9 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['star-wars-episode-vii---the-force-awakens', '9', 'TheQuietGamer']
# Reviewer: TheQuietGamer Score: 9 favorite_movie: star-wars-episode-vii---the-force-awakens
# ['star-wars-episode-vii---the-force-awakens', '10', 'MonkiReviews']
# Reviewer: MonkiReviews Score: 10 favorite_movie: star-wars-episode-vii---the-force-awakens

# %%
#creating csv file with the fields Movie, Userscore and Reviewer
fields = [['Movie', 'Userscore', 'Reviewer']]
file = open('moviesKaoutar.csv', 'w+', newline ='') 
with file:     
    write = csv.writer(file) 
    write.writerows(fields)
    write.writerows(List2)
